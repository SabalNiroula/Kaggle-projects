# %% [markdown]
# # 1. Environment Configuration

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('haberman.csv', header=None,
                   names=['age', 'year_of_treatment', 'positive_lymph_nodes', 'survival_status_after_5_years'])

# %%
data.head()
# Out:
#    age  year_of_treatment  positive_lymph_nodes  survival_status_after_5_years
# 0   30                 64                     1                              1
# 1   30                 62                     3                              1
# 2   30                 65                     0                              1
# 3   31                 59                     2                              1
# 4   31                 65                     4                              1

# %% [markdown]
# # 2. Data Preparation

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            306 non-null    int64
#  1   year_of_treatment              306 non-null    int64
#  2   positive_lymph_nodes           306 non-null    int64
#  3   survival_status_after_5_years  306 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %% [markdown]
# ## Observation
#
# - There are no missing dataset so we dont need data inputation.
# - The datatype of 'survival_status_after_5_years' column is integer. It has to be converted to categorical datatype.
# - The values of 'survival_status_after_5_years' column are not meanigful. Hence they are mapped to 'yes' (survived after 5 years) and 'no' (not survived after 5 years)

# %%
mapping = {1:'yes', 2:'no'}
data.survival_status_after_5_years = data.survival_status_after_5_years.map(mapping)
data.head()
# Out:
#    age  year_of_treatment  positive_lymph_nodes survival_status_after_5_years
# 0   30                 64                     1                           yes
# 1   30                 62                     3                           yes
# 2   30                 65                     0                           yes
# 3   31                 59                     2                           yes
# 4   31                 65                     4                           yes

# %%
# Lets change survival_status column into categorical data
data.survival_status_after_5_years = data.survival_status_after_5_years.astype("category")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            306 non-null    int64
#  1   year_of_treatment              306 non-null    int64
#  2   positive_lymph_nodes           306 non-null    int64
#  3   survival_status_after_5_years  306 non-null    category
# dtypes: category(1), int64(3)
# memory usage: 7.7 KB

# %% [markdown]
# # 3. High Level Statistics

# %%
data.describe()
# Out:
#               age  year_of_treatment  positive_lymph_nodes
# count  306.000000         306.000000            306.000000
# mean    52.457516          62.852941              4.026144
# std     10.803452           3.249405              7.189654
# min     30.000000          58.000000              0.000000
# 25%     44.000000          60.000000              0.000000
# 50%     52.000000          63.000000              1.000000
# 75%     60.750000          65.750000              4.000000
# max     83.000000          69.000000             52.000000

# %% [markdown]
# # Univariate Analysis

# %%
# distplot (distribution plot) used to see how a 
print((list(data.columns[:-1])))

for columnName in (list(data.columns)[:-1]):
    fg = sns.FacetGrid(data=data, hue='survival_status_after_5_years', height=4)
    fg.map(sns.distplot, columnName, kde=True).add_legend()
    plt.show()
# Out:
# ['age', 'year_of_treatment', 'positive_lymph_nodes']

# %% [markdown]
# # Multivariate Analysis

# %%
# boxplot
sns.boxplot(data=data)
plt.show()
